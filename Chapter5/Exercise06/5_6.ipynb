# %% [markdown]
# <blockquote>
#     <h1>Exercise 5.6</h1>
#     <p>We continue to consider the use of a logistic regression model to predict the probability of $\mathrm{default}$ using $\mathrm{income}$ and $\mathrm{balance}$ on the <code>Default</code> data set. In particular, we will now compute estimates for the standard errors of the $\mathrm{income}$ and $\mathrm{balance}$ logistic regression coefficients in two different ways: (1) using the bootstrap, and (2) using the standard formula for computing the standard errors in the <code>glm()</code> function. Do not forget to set a random seed before beginning your analysis.</p>
#     <ol>
#         <li>Using the <code>summary()</code> and <code>glm()</code> functions, determine the estimated standard errors for the coefficients associated with $\mathrm{income}$ and $\mathrm{balance}$ in a multiple logistic regression model that uses both predictors.</li>
#         <li>Write a function, <code>boot.fn()</code>, that takes as input the <code>Default</code> data set as well as an index of the observations, and that outputs the coefficient estimates for $\mathrm{income}$ and $\mathrm{balance}$ in the multiple logistic regression model.</li>
#         <li>Use the <code>boot()</code> function together with your <code>boot.fn()</code> function to estimate the standard errors of the logistic regression coefficients for $\mathrm{income}$ and $\mathrm{balance}$.</li>
#         <li>Comment on the estimated standard errors obtained using the <code>glm()</code> function and using your bootstrap function.</li>
#     </ol>
# </blockquote>

# %%
import pandas as pd
import numpy as np

# https://stackoverflow.com/questions/34398054/ipython-notebook-cell-multiple-outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from sklearn.utils import resample
import statsmodels.api as sm

# %% [markdown]
# <h3>Exercise 5.6.1</h3>
# <blockquote>
#     <i>Using the <code>summary()</code> and <code>glm()</code> functions, determine the estimated standard errors for the coefficients associated with $\mathrm{income}$ and $\mathrm{balance}$ in a multiple logistic regression model that uses both predictors.</i>
# </blockquote>

# %%
df = pd.read_csv("../../DataSets/Default/Default.csv")
df['default01'] = np.where(df['default'] == 'Yes', 1, 0)
df.insert(0, 'Intercept', 1)
targetColumn = ['default01']
descriptiveColumns = ['Intercept', 'balance', 'income']
df_X = df[descriptiveColumns]
df_Y = df[targetColumn]
model = sm.Logit(df_Y, df_X)
fitted = model.fit()
fitted.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.078948
#          Iterations 10
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              default01   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9997
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 12 Jan 2020   Pseudo R-squ.:                  0.4594
# Time:                        22:24:19   Log-Likelihood:                -789.48
# converged:                       True   LL-Null:                       -1460.3
# Covariance Type:            nonrobust   LLR p-value:                4.541e-292
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -11.5405      0.435    -26.544      0.000     -12.393     -10.688
# balance        0.0056      0.000     24.835      0.000       0.005       0.006
# income      2.081e-05   4.99e-06      4.174      0.000     1.1e-05    3.06e-05
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.14 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %% [markdown]
# <h3>Exercise 5.6.2</h3>
# <blockquote>
#     <i>Write a function, <code>boot.fn()</code>, that takes as input the <code>Default</code> data set as well as an index of the observations, and that outputs the coefficient estimates for $\mathrm{income}$ and $\mathrm{balance}$ in the multiple logistic regression model.</i>
# </blockquote>

# %%
def boot_fn(df, mask=None):
    targetColumn = ['default01']
    descriptiveColumns = ['Intercept', 'balance', 'income']
    if mask is None:
        df_X = df[descriptiveColumns]
        df_Y = df[targetColumn]
    else:
        df_X = df[mask][descriptiveColumns]
        df_Y = df[mask][targetColumn]

    model = sm.Logit(df_Y, df_X)
    fitted = model.fit()
    return fitted.params
    
boot_fn(df=df, mask=df['student'] == 'Yes')
boot_fn(df=df, mask=df['student'] == 'No')
boot_fn(df=df, mask=None)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.095624
#          Iterations 10
# Intercept   -11.507699
# balance       0.005598
# income        0.000016
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.071431
#          Iterations 10
# Intercept   -10.936996
# balance       0.005818
# income        0.000002
# dtype: float64
# Optimization terminated successfully.
#          Current function value: 0.078948
#          Iterations 10
# Intercept   -11.540468
# balance       0.005647
# income        0.000021
# dtype: float64

# %% [markdown]
# <h3>Exercise 5.6.3</h3>
# <blockquote>
#     <i>Use the <code>boot()</code> function together with your <code>boot.fn()</code> function to estimate the standard errors of the logistic regression coefficients for $\mathrm{income}$ and $\mathrm{balance}$.</i>
# </blockquote>

# %%
sample_size = int(1.0 * df.shape[0])
B = 1000

df_std_err_coef = pd.DataFrame(np.empty((B, 3)), columns=descriptiveColumns)

for r in range(0, B):
    boot = resample(df, replace=True, n_samples=sample_size, random_state=r)
    df_std_err_coef.iloc[r] = boot_fn(df=boot)

average_intercept = df_std_err_coef["Intercept"].mean()
average_balance = df_std_err_coef["balance"].mean()
average_income = df_std_err_coef["income"].mean()

std_err_intercept = ((1/(B-1))*np.sum((df_std_err_coef['Intercept'] - average_intercept)**2))**0.5
std_err_balance = ((1/(B-1))*np.sum((df_std_err_coef['balance'] - average_balance)**2))**0.5
std_err_income = ((1/(B-1))*np.sum((df_std_err_coef['income'] - average_income)**2))**0.5
# Out:
# Optimization terminated successfully.
#          Current function value: 0.077812
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078583
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080187
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079723
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077127
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075327
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080034
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083545
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078794
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.090949
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083624
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082180
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077399
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073657
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074980
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079403
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073501
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082371
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075281
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080444
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077660
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078632
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083531
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077188
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077169
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076156
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075978
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074910
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074515
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083496
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079769
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074057
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078851
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078761
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075740
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080110
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079706
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075302
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078118
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077448
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079585
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075107
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078504
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075957
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080414
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081067
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074668
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083333
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074953
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079647
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082397
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077596
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079268
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079380
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082092
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083584
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080095
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080237
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078400
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072032
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075989
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079849
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071137
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077589
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076885
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078788
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078811
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074449
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079867
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071899
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073601
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073324
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.086914
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075715
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080576
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078745
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081818
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083682
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072572
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081799
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082737
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075462
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080212
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074971
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076399
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081344
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077512
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079328
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079527
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081869
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074441
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080105
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082059
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080195
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079033
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076926
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083527
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084105
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077959
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080709
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072215
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.090080
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077471
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075331
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078047
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077338
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076406
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078397
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078824
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083333
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073941
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075962
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073083
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076834
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081999
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081261
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077789
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084266
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075553
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077313
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080984
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085517
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079405
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081893
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079964
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078132
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078755
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077330
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078380
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078450
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079309
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075198
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078254
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078625
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.087372
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080947
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077449
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079542
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081109
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077339
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.070570
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085545
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074022
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081784
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081595
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077111
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075785
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077758
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080531
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076661
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080575
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081283
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074881
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076231
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080266
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.086662
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078818
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084258
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080403
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082634
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074365
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076013
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076859
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081158
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078774
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076891
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080004
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078037
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.087092
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076549
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082131
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079630
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083663
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080822
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078624
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074989
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081846
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075379
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072743
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077211
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082879
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076396
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079884
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083240
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074727
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080078
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078539
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085505
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080316
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078739
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081195
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081029
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083920
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080549
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082869
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078629
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081285
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083907
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080974
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077962
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081774
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078012
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076891
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077647
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081168
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080930
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073071
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078266
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075858
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083101
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081616
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077732
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076909
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071631
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079340
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080498
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082454
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080085
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.086730
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077147
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.088937
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079529
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080558
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073405
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078988
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083372
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.086769
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071783
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.086106
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077545
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074756
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081052
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076184
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075167
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083928
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074011
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080182
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079375
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077964
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080569
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083877
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082454
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077892
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082234
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076115
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080085
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077311
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079518
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079127
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077483
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078241
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.086108
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079336
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081105
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075999
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077299
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077553
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074234
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085463
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075132
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078526
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084515
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078296
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076499
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075430
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077744
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078569
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080588
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071563
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078620
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078272
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080685
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.